# %% [markdown]
# <a href="https://colab.research.google.com/github/Legewen/LegewenPortOrder/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

html_content = """
<!DOCTYPE html>
<html lang='id'>
<head>
    <meta charset='UTF-8'>
    <meta name='viewport' content='width=device-width, initial-scale=1.0'>
    <link href='https://fonts.googleapis.com/css2?family=Playfair+Display:wght@900&family=Montserrat:wght@400;700;900&display=swap' rel='stylesheet'>
    <link rel='stylesheet' href='https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0/css/all.min.css'>
    <script src='https://cdnjs.cloudflare.com/ajax/libs/gsap/3.12.2/gsap.min.js'></script>
    <style>
        :root {
            --navy-main: #000080;
            --navy-light: #0000cc;
            --white: #ffffff;
            --bg-image: url('https://images.unsplash.com/photo-1541701494587-cb58502866ab?ixlib=rb-4.0.3&auto=format&fit=crop&w=1600&q=80');
            --overlay: rgba(255, 255, 255, 0.85);
            --card-bg: rgba(255, 255, 255, 0.7);
            --text-color: #000080;
            --heading-color: #000080;
            --service-title: #000000;
            --card-border: rgba(0, 0, 128, 0.1);
            --card-shadow: 0 10px 30px rgba(0, 0, 128, 0.05);
            --card-shadow-hover: 0 20px 40px rgba(0, 0, 128, 0.15);
            --grad-primary: linear-gradient(135deg, #000080 0%, #0055ff 100%);
            --grad-wa: linear-gradient(135deg, #25d366 0%, #128c7e 100%);
            scroll-behavior: smooth;
        }

        [data-theme='dark'] {
            --bg-image: url('https://images.unsplash.com/photo-1550684848-fac1c5b4e853?ixlib=rb-4.0.3&auto=format&fit=crop&w=1600&q=80');
            --overlay: rgba(0, 0, 30, 0.9);
            --card-bg: rgba(255, 255, 255, 0.05);
            --text-color: #ffffff;
            --heading-color: #ffffff;
            --service-title: #ffffff;
            --card-border: rgba(255, 255, 255, 0.1);
            --card-shadow: 0 10px 30px rgba(0, 0, 0, 0.3);
            --card-shadow-hover: 0 20px 50px rgba(0, 0, 0, 0.5);
        }

        * {
            margin: 0; padding: 0; box-sizing: border-box;
            transition: background 0.6s, color 0.6s, border 0.6s;
        }

        body {
            font-family: 'Montserrat', sans-serif;
            background: var(--bg-image) no-repeat center center fixed;
            background-size: cover;
            color: var(--text-color);
            min-height: 100vh;
            display: flex;
            flex-direction: column;
        }

        body::before {
            content: '';
            position: fixed;
            top: 0; left: 0; width: 100%; height: 100%;
            background: var(--overlay);
            z-index: -1;
        }

        header {
            padding: 1rem 8%;
            display: flex; justify-content: space-between; align-items: center;
            backdrop-filter: blur(20px); -webkit-backdrop-filter: blur(20px);
            position: sticky; top: 0; z-index: 1000;
            border-bottom: 1px solid var(--card-border);
            background: rgba(255,255,255,0.1);
        }

        .logo {
            font-weight: 900; font-size: 1.8rem; letter-spacing: -1px;
            color: var(--navy-main);
            text-decoration: none;
        }
        [data-theme='dark'] .logo { color: #fff; }

        nav ul {
            display: flex; list-style: none; gap: 30px; align-items: center;
        }

        nav a {
            text-decoration: none; color: var(--text-color); font-weight: 700;
            font-size: 0.85rem; text-transform: uppercase; letter-spacing: 1px;
            opacity: 0.7; transition: 0.3s;
        }

        nav a:hover { opacity: 1; }

        .hero {
            text-align: center;
            padding: 120px 8% 60px 8%;
            flex-grow: 1;
        }

        .hero h1 {
            font-family: 'Playfair Display', serif;
            font-size: clamp(3rem, 10vw, 5rem);
            color: var(--heading-color);
            margin-bottom: 20px;
        }

        .grid-container {
            display: grid; grid-template-columns: repeat(auto-fit, minmax(300px, 1fr));
            gap: 40px; padding: 0 8% 100px 8%;
        }

        .service-card {
            background: var(--card-bg); backdrop-filter: blur(10px);
            border-radius: 40px; padding: 50px 30px; text-align: center;
            border: 1px solid var(--card-border); cursor: pointer;
            box-shadow: var(--card-shadow);
            transition: 0.4s cubic-bezier(0.175, 0.885, 0.32, 1.275);
        }

        .service-card:hover {
            transform: translateY(-12px);
            box-shadow: var(--card-shadow-hover);
        }

        .service-card h3 {
            color: var(--service-title); font-weight: 900; font-size: 1.5rem; margin: 15px 0;
        }

        .price-tag { display: inline-block; padding: 10px 25px; background: var(--navy-main); color: white; border-radius: 50px; margin-top: 20px; font-weight: 700; }

        footer { background: rgba(255,255,255,0.1); backdrop-filter: blur(20px); border-top: 1px solid var(--card-border); padding: 50px 8% 30px 8%; text-align: center; }
        .footer-content { display: flex; justify-content: space-between; align-items: center; flex-wrap: wrap; gap: 20px; margin-bottom: 30px; }
        .social-links { display: flex; gap: 20px; }
        .social-links a { width: 45px; height: 45px; border-radius: 50%; background: var(--navy-main); color: white; display: flex; align-items: center; justify-content: center; text-decoration: none; transition: 0.3s; }
        .social-links a:hover { transform: scale(1.1); filter: brightness(1.2); }

        .overlay-page {
            position: fixed; top: 0; left: 100%; width: 100%; height: 100%;
            background: var(--bg-image) no-repeat center center fixed;
            background-size: cover; z-index: 20000; overflow-y: auto; padding: 8% 0;
        }

        .overlay-page::before {
            content: ''; position: absolute; top: 0; left: 0; width: 100%; height: 100%;
            background: var(--overlay); z-index: -1;
        }

        .content-card {
            background: var(--card-bg); backdrop-filter: blur(30px); padding: 50px;
            border-radius: 40px; max-width: 850px; border: 1px solid var(--card-border);
            margin: auto; text-align: center;
        }

        .form-group { margin-bottom: 20px; text-align: left; }
        label { display: block; font-weight: 700; margin-bottom: 8px; font-size: 0.9rem; }
        input, textarea { width: 100%; padding: 12px 15px; border-radius: 12px; border: 1px solid var(--card-border); background: rgba(255,255,255,0.5); font-family: inherit; color: var(--text-color); }
        textarea { resize: none; }

        .btn-submit {
            background: var(--grad-wa); color: white; border: none; padding: 15px 30px;
            border-radius: 50px; cursor: pointer; font-weight: 900; width: 100%;
            font-size: 1rem; display: flex; align-items: center; justify-content: center; gap: 10px;
            transition: all 0.4s cubic-bezier(0.23, 1, 0.32, 1);
            box-shadow: 0 10px 20px rgba(37, 211, 102, 0.2);
            position: relative; overflow: hidden;
        }
        .btn-submit:hover {
            transform: translateY(-3px);
            filter: brightness(1.15);
            box-shadow: 0 15px 30px rgba(37, 211, 102, 0.4);
        }
        .btn-submit:active { transform: translateY(-1px); }

        .btn-primary {
            background: var(--grad-primary); color: white; border: none; padding: 15px 40px;
            border-radius: 50px; cursor: pointer; font-weight: 900; font-size: 1rem;
            text-decoration: none; display: inline-block; margin-top: 30px;
            transition: all 0.4s cubic-bezier(0.23, 1, 0.32, 1);
            box-shadow: 0 10px 20px rgba(0, 0, 128, 0.2);
        }
        .btn-primary:hover {
            transform: translateY(-5px) scale(1.05);
            filter: brightness(1.2);
            box-shadow: 0 20px 40px rgba(0, 0, 128, 0.3);
        }
        .btn-primary:active { transform: translateY(-2px); }

        .btn-order-nav {
            background: var(--navy-main); color: white !important; padding: 10px 25px;
            border-radius: 50px; cursor: pointer; font-weight: 700; text-decoration: none; border: none;
            text-transform: uppercase; font-size: 0.75rem;
            transition: all 0.3s ease;
        }
        .btn-order-nav:hover { transform: scale(1.08); background: var(--navy-light); }

        .detail-icon { font-size: 5rem; color: var(--navy-main); margin-bottom: 20px; opacity: 0.9; }

        @media (max-width: 768px) {
            nav { display: none; }
            .footer-content { flex-direction: column; }
            .content-card { padding: 30px; margin: 20px; }
        }
    </style>
</head>
<body data-theme='light'>
    <header>
        <a href='#' class='logo'>LEGEWEN.</a>
        <nav>
            <ul>
                <li><a href='#'>Home</a></li>
                <li><a href='#services'>Services</a></li>
                <li><a href='https://wa.me/6285775248893'>Contact</a></li>
            </ul>
        </nav>
        <div style='display:flex; align-items:center; gap:15px;'>
            <button class='btn-order-nav' onclick='openOrder("Layanan")'>Order Now</button>
            <button onclick='toggleTheme()' style='background:none; border:none; cursor:pointer; color:inherit; font-size:1.2rem;'>
                <i class='fas fa-moon' id='theme-icon'></i>
            </button>
        </div>
    </header>

    <section class='hero'>
        <p style='letter-spacing: 8px; font-weight: 900; opacity: 0.6; margin-bottom: 10px;'>PREMIUM SERVICES</p>
        <h1>CREATIVE VISION.</h1>
    </section>

    <div class='grid-container' id='services'>
        <div class='service-card' onclick='openDetail("joki-tugas")'>
            <i class='fas fa-wand-magic-sparkles' style='font-size: 3.5rem; color: var(--navy-main); opacity:0.8;'></i>
            <h3>Joki Tugas</h3>
            <p>Akademik tepat waktu.</p>
            <span class='price-tag'>Rp 25k+</span>
        </div>
        <div class='service-card' onclick='openDetail("joki-web")'>
            <i class='fas fa-code-branch' style='font-size: 3.5rem; color: var(--navy-main); opacity:0.8;'></i>
            <h3>Joki Web</h3>
            <p>Website modern & responsif.</p>
            <span class='price-tag'>Rp 50k+</span>
        </div>
        <div class='service-card' onclick='openDetail("premium-art")'>
            <i class='fas fa-gem' style='font-size: 3.5rem; color: var(--navy-main); opacity:0.8;'></i>
            <h3>Premium Art</h3>
            <p>Desain visual eksklusif.</p>
            <span class='price-tag'>Rp 50k+</span>
        </div>
    </div>

    <footer>
        <div class='footer-content'>
            <div style='text-align: left;'>
                <h2 class='logo'>LEGEWEN.</h2>
                <p style='opacity: 0.6; font-size: 0.9rem; margin-top: 10px;'>Elevating your digital presence with creative solutions.</p>
            </div>
            <div class='social-links'>
                <a href='https://wa.me/6285775248893'><i class='fab fa-whatsapp'></i></a>
                <a href='#'><i class='fab fa-instagram'></i></a>
                <a href='#'><i class='fab fa-twitter'></i></a>
            </div>
        </div>
        <p style='font-weight: 700; opacity: 0.4; font-size: 0.8rem; border-top: 1px solid var(--card-border); padding-top: 20px;'>&copy; 2024 LEGEWEN ARTISTRY. ALL RIGHTS RESERVED.</p>
    </footer>

    <div id='detail-page' class='overlay-page'>
        <div class='content-card'>
            <i id='detail-icon' class='fas detail-icon'></i>
            <h2 id='detail-name' style='font-family: "Playfair Display", serif; font-size: 3rem; margin-bottom: 20px;'></h2>
            <p id='detail-desc' style='font-size: 1.1rem; line-height: 1.8; opacity: 0.8; margin-bottom: 20px;'></p>
            <ul id='detail-features' style='list-style: none; margin-bottom: 30px; text-align: left; max-width: 400px; margin-left: auto; margin-right: auto;'></ul>
            <button class='btn-primary' id='detail-cta-btn'>Pesan Sekarang</button>
            <br>
            <button class='btn-order-nav' style='background:none; color:var(--text-color) !important; margin-top:20px; opacity:0.6;' onclick='closeDetail()'>Kembali ke Home</button>
        </div>
    </div>

    <div id='order-page' class='overlay-page'>
        <div class='content-card' style='max-width: 700px;'>
            <h2 id='order-title' style='font-family: "Playfair Display", serif; font-size: 2.2rem; margin-bottom: 25px;'>Order Form</h2>
            <div class='form-group'>
                <label>Nama Lengkap</label>
                <input type='text' id='userName' placeholder='Masukkan nama Anda...'>
            </div>
            <div class='form-group'>
                <label>Email / Kontak Aktif</label>
                <input type='text' id='userContact' placeholder='example@mail.com / 0812...'>
            </div>
            <div class='form-group'>
                <label>Detail Pesanan</label>
                <textarea id='orderDetails' rows='4' placeholder='Jelaskan tugas atau desain yang Anda butuhkan...'></textarea>
            </div>
            <div class='form-group'>
                <label>Jumlah / Satuan</label>
                <input type='text' id='orderQty' placeholder='Contoh: 1 File / 2 Halaman'>
            </div>
            <button class='btn-submit' onclick='sendOrder()'>
                <i class='fab fa-whatsapp'></i> Kirim via WhatsApp
            </button>
            <button class='btn-order-nav' style='background:none; color:var(--text-color) !important; width:100%; margin-top:10px; opacity:0.6;' onclick='closeOrder()'>Kembali</button>
        </div>
    </div>

    <script>
        let currentService = "";

        const serviceData = {
            "joki-tugas": {
                name: "Joki Tugas",
                icon: "fa-wand-magic-sparkles",
                desc: "Kami membantu Anda menyelesaikan berbagai tugas akademik, mulai dari penulisan esai, laporan praktikum, hingga tugas coding kompleks dengan hasil berkualitas dan bebas plagiasi.",
                features: ["✓ Pengerjaan Cepat", "✓ Penulis Berpengalaman", "✓ Revisi Gratis", "✓ Kerahasiaan Terjamin"]
            },
            "joki-web": {
                name: "Joki Web",
                icon: "fa-code-branch",
                desc: "Transformasikan ide Anda menjadi website yang nyata. Kami membangun Landing Page, Portfolio, atau Web Aplikasi menggunakan teknologi terbaru yang responsif dan SEO-Friendly.",
                features: ["✓ Desain Modern", "✓ Mobile Responsive", "✓ Fast Loading", "✓ Free Maintenance 1 Bulan"]
            },
            "premium-art": {
                name: "Premium Art",
                icon: "fa-gem",
                desc: "Layanan desain visual tingkat tinggi untuk kebutuhan branding, ilustrasi custom, hingga desain UI/UX yang akan membuat produk Anda tampil berbeda dari kompetitor.",
                features: ["✓ High Resolution", "✓ Full Exclusive Rights", "✓ Multiple File Formats", "✓ Source File Included"]
            }
        };

        function openDetail(key) {
            const data = serviceData[key];
            currentService = data.name;

            document.getElementById('detail-name').innerText = data.name;
            document.getElementById('detail-desc').innerText = data.desc;
            document.getElementById('detail-icon').className = 'fas detail-icon ' + data.icon;

            const featList = document.getElementById('detail-features');
            featList.innerHTML = "";
            data.features.forEach(f => {
                let li = document.createElement('li');
                li.style.marginBottom = "10px";
                li.style.fontWeight = "700";
                li.innerText = f;
                featList.appendChild(li);
            });

            document.getElementById('detail-cta-btn').onclick = () => openOrder(data.name);

            gsap.to("#detail-page", { left: 0, duration: 0.8, ease: "power3.inOut" });
        }

        function closeDetail() {
            gsap.to("#detail-page", { left: "100%", duration: 0.8, ease: "power3.inOut" });
        }

        function openOrder(serviceName) {
            currentService = serviceName;
            document.getElementById('order-title').innerText = "Order: " + serviceName;
            gsap.to("#order-page", { left: 0, duration: 0.8, ease: "power3.inOut" });
        }

        function closeOrder() {
            gsap.to("#order-page", { left: "100%", duration: 0.8, ease: "power3.inOut" });
        }

        function sendOrder() {
            const name = document.getElementById('userName').value.trim();
            const contact = document.getElementById('userContact').value.trim();
            const details = document.getElementById('orderDetails').value.trim();
            const qty = document.getElementById('orderQty').value.trim();

            if(!name || !contact || !details || !qty) {
                alert("⚠️ Mohon lengkapi semua data formulir sebelum mengirim.");
                return;
            }

            const phone = "6285775248893";
            const text = `Halo Admin Legewen Artistry!%0A%0ASaya ingin memesan layanan:%0A*Layanan:* ${currentService}%0A*Nama:* ${name}%0A*Kontak:* ${contact}%0A*Detail:* ${details}%0A*Jumlah:* ${qty}%0A%0AMohon info lebih lanjut ya. Terima kasih!`;
            window.open(`https://wa.me/${phone}?text=${text}`, '_blank');
        }

        function toggleTheme() {
            const body = document.body;
            const icon = document.getElementById('theme-icon');
            if (body.getAttribute('data-theme') === 'light') {
                body.setAttribute('data-theme', 'dark');
                icon.className = 'fas fa-sun';
            } else {
                body.setAttribute('data-theme', 'light');
                icon.className = 'fas fa-moon';
            }
        }
    </script>
</body>
</html>
"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang='id'>
# <head>
#     <meta charset='UTF-8'>
#     <meta name='viewport' content='width=device-width, initial-scale=1.0'>
#     <link href='https://fonts.googleapis.com/css2?family=Playfair+Display:wght@900&family=Montserrat:wght@400;700;900&display=swap' rel='stylesheet'>
#     <link rel='stylesheet' href='https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0/css/all.min.css'>
#     <script src='https://cdnjs.cloudflare.com/ajax/libs/gsap/3.12.2/gsap.min.js'></script>
#     <style>
#         :root {
#             --navy-main: #000080;
#             --navy-light: #0000cc;
#             --white: #ffffff;
#             --bg-image: url('https://images.unsplash.com/photo-1541701494587-cb58502866ab?ixlib=rb-4.0.3&auto=format&fit=crop&w=1600&q=80');
#             --overlay: rgba(255, 255, 255, 0.85);
#             --card-bg: rgba(255, 255, 255, 0.7);
#             --text-color: #000080;
#             --heading-color: #000080;
# ...
